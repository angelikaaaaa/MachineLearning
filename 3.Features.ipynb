# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_transaction = pd.read_csv('/content/drive/My Drive/train_transaction.csv') 
df_identity = pd.read_csv('/content/drive/My Drive/train_identity.csv') 
df = df_identity.merge(df_transaction, on=['TransactionID'])
del df_transaction, df_identity

# %%
hours = df['TransactionDT'] / (3600)        
rozkodowanie = np.floor(hours) % 24
df['hours'] = rozkodowanie

# %%
catFeatures=['id_12','id_15', 'id_16', 'id_28', 'id_29', 'id_30', 'id_31', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'DeviceType', 'DeviceInfo', 'ProductCD', 'card4', 
             'card6', 'P_emaildomain', 'R_emaildomain', 'M1',	'M2',	'M3',	'M4',	'M5',	'M6',	'M7',	'M8',	'M9', 'C1','V12','V13','V14','V15','V16']

numFeatures=list(df)
for x in catFeatures:
  numFeatures.remove(x)

numFeatures.remove('isFraud')
df['isFraud'] = df['isFraud'].astype(int)

# %%
#wywalenie zmiennych z 80% missingów
df = df.drop(columns=['TransactionID', 'TransactionDT'])
missingi = [df[col].isnull().sum() / df.shape[0] for col in df.columns]
kolumny = [df.columns[i] for i in range(df.shape[1]) if missingi[i] > 0.8]
df = df.drop(kolumny, axis=1)
#wywalenie zmiennych gdzie 90% to te same informacje
identyczne = [c for c in df.columns if df[c].value_counts(normalize=True).values[0] > 0.9]
do_wywalenia = identyczne
do_wywalenia.remove('isFraud')
df = df.drop(do_wywalenia, axis=1)

# %%
df.shape

# %%
catFeatures=['id_12','id_15', 'id_16', 'id_28', 'id_29', 'id_30', 'id_31', 'id_33', 'id_34', 'id_35', 'id_37', 'id_38', 'DeviceType', 'DeviceInfo', 'ProductCD', 'card4', 
             'card6', 'M4', 'P_emaildomain', 'R_emaildomain','V15',	'V16',	'V19',	'V20',	'V33',	'V34',	'V37',	'V38']


df.fillna(-999, inplace=True)
for x in catFeatures:
  df[x] = df[x].astype(str)

# %%
print('Przed transformacją: ')
print('Poziomy id_30: ',len(df['id_30'].value_counts()))
print('Poziomy id_31: ',len(df['id_31'].value_counts()))
print('Poziomy DeviceInfo: ',len(df['DeviceInfo'].value_counts()))
print('Poziomy P_emaildomain: ',len(df['P_emaildomain'].value_counts()))
print('Poziomy R_emaildomain: ',len(df['R_emaildomain'].value_counts()))

# %%
#@title Transformacja zmiennych
df['id_30'].replace({'Android':'Android',
'Android 5.0.2':'Android',
'Android 5.1.1':'Android',
'Android 6.0':'Android',
'Android 6.0.1':'Android',
'Android 7.0':'Android',
'Android 7.1.1':'Android',
'Android 8.0.0':'Android',
'iOS':'IOS',
'iOS 10.0.2':'IOS',
'iOS 10.2.0':'IOS',
'iOS 10.2.1':'IOS',
'iOS 10.3.1':'IOS',
'iOS 10.3.2':'IOS',
'iOS 10.3.3':'IOS',
'iOS 11.0.0':'IOS',
'iOS 11.0.1':'IOS',
'iOS 11.0.2':'IOS',
'iOS 11.0.3':'IOS',
'iOS 11.1.0':'IOS',
'iOS 11.1.1':'IOS',
'iOS 11.1.2':'IOS',
'iOS 9.3.5':'IOS',
'Linux':'Linux',
'Mac':'Mac',
'Mac OS X 10.10':'Mac',
'Mac OS X 10.11':'Mac',
'Mac OS X 10.12':'Mac',
'Mac OS X 10.13':'Mac',
'Mac OS X 10.9':'Mac',
'Mac OS X 10_10_5':'Mac',
'Mac OS X 10_11_5':'Mac',
'Mac OS X 10_11_6':'Mac',
'Mac OS X 10_12':'Mac',
'Mac OS X 10_12_3':'Mac',
'Mac OS X 10_12_5':'Mac',
'Mac OS X 10_12_6':'Mac',
'Mac OS X 10_13_1':'Mac',
'Mac OS X 10_7_5':'Mac',
'Mac OS X 10_8_5':'Mac',
'Mac OS X 10_9_5':'Mac',
'Windows 10':'Windows',
'Windows 7':'Windows',
'Windows 8.1':'Windows',
'Windows Vista':'Windows',
'iOS 11.2.1 ':'IOS',
'iOS 11.3.0':'IOS',
'iOS 11.2.6':'IOS',
'Mac OS X 10_13_2':'Mac',
'iOS 11.2.5':'IOS',
'iOS 11.2.2':'IOS',
'Mac OS X 10_13_3':'Mac',
'iOS 11.2.0':'IOS',
'Mac OS X 10_13_4':'Mac',
'Android 8.1.0':'Android',
'Windows 8':'Windows',
'iOS 11.3.1':'IOS',
'Windows XP':'Windows',
'Mac OS X 10_12_4':'Mac',
'iOS 10.1.1':'IOS',
'Android 4.4.2':'Android',
'Mac OS X 10_11_3':'Mac',
'Mac OS X 10_11_4':'Mac',
'Mac OS X 10_6_8':'Mac',
'Mac OS X 10.6':'Mac',
'Mac OS X 10_12_1':'Mac',
'Android 5.0':'Android',
'Android 7.1.2':'Android',
'Mac OS X 10_12_2':'Mac',
'iOS 11.4.0':'IOS',
'Mac OS X 10_13_5':'Mac',
'iOS 11.4.1':'IOS',
'func':'Inne',
'other':'Inne',
}, inplace=True)



df['id_31'].replace({'android' : 'android' ,
'android browser 4.0' : 'android' ,
'android webview 4.0' : 'android' ,
'aol' : 'inne' ,
'BLU/Dash' : 'inne' ,
'Cherry' : 'inne' ,
'chrome' : 'chrome' ,
'chrome 43.0 for android' : 'chrome' ,
'chrome 46.0 for android' : 'chrome' ,
'chrome 49.0' : 'chrome' ,
'chrome 49.0 for android' : 'chrome' ,
'chrome 50.0 for android' : 'chrome' ,
'chrome 51.0' : 'chrome' ,
'chrome 51.0 for android' : 'chrome' ,
'chrome 52.0 for android' : 'chrome' ,
'chrome 53.0 for android' : 'chrome' ,
'chrome 54.0 for android' : 'chrome' ,
'chrome 55.0' : 'chrome' ,
'chrome 55.0 for android' : 'chrome' ,
'chrome 56.0' : 'chrome' ,
'chrome 56.0 for android' : 'chrome' ,
'chrome 57.0' : 'chrome' ,
'chrome 57.0 for android' : 'chrome' ,
'chrome 58.0' : 'chrome' ,
'chrome 58.0 for android' : 'chrome' ,
'chrome 59.0' : 'chrome' ,
'chrome 59.0 for android' : 'chrome' ,
'chrome 60.0' : 'chrome' ,
'chrome 60.0 for android' : 'chrome' ,
'chrome 61.0' : 'chrome' ,
'chrome 61.0 for android' : 'chrome' ,
'chrome 62.0' : 'chrome' ,
'chrome 62.0 for android' : 'chrome' ,
'chrome 62.0 for ios' : 'chrome' ,
'chrome 63.0' : 'chrome' ,
'chrome 63.0 for android' : 'chrome' ,
'chrome 63.0 for ios' : 'chrome' ,
'chrome 64.0' : 'chrome' ,
'chrome 64.0 for android' : 'chrome' ,
'chrome 64.0 for ios' : 'chrome' ,
'chrome 65.0' : 'chrome' ,
'chrome 65.0 for android' : 'chrome' ,
'chrome 65.0 for ios' : 'chrome' ,
'chrome 66.0' : 'chrome' ,
'chrome 66.0 for android' : 'chrome' ,
'chrome 66.0 for ios' : 'chrome' ,
'chrome 67.0' : 'chrome' ,
'chrome 67.0 for android' : 'chrome' ,
'chrome 69.0' : 'chrome' ,
'chrome generic' : 'chrome' ,
'chrome generic for android' : 'chrome' ,
'chromium' : 'chrome' ,
'comodo' : 'inne' ,
'cyberfox' : 'inne' ,
'edge' : 'edge' ,
'edge 13.0' : 'edge' ,
'edge 14.0' : 'edge' ,
'edge 15.0' : 'edge' ,
'edge 16.0' : 'edge' ,
'edge 17.0' : 'edge' ,
'facebook' : 'inne' ,
'firefox' : 'firefox' ,
'firefox 47.0' : 'firefox' ,
'firefox 48.0' : 'firefox' ,
'firefox 52.0' : 'firefox' ,
'firefox 55.0' : 'firefox' ,
'firefox 56.0' : 'firefox' ,
'firefox 57.0' : 'firefox' ,
'firefox 58.0' : 'firefox' ,
'firefox 59.0' : 'firefox' ,
'firefox 60.0' : 'firefox' ,
'firefox generic' : 'firefox' ,
'firefoxmobile 61.0' : 'firefox' ,
'Generic/Android' : 'inne' ,
'Generic/Android 7.0' : 'inne' ,
'google' : 'chrome' ,
'google search application 48.0' : 'chrome' ,
'google search application 49.0' : 'chrome' ,
'icedragon' : 'inne' ,
'ie' : 'explorer' ,
'ie 11.0 for desktop' : 'explorer' ,
'ie 11.0 for tablet' : 'explorer' ,
'Inco/Minion' : 'inne' ,
'iron' : 'inne' ,
'Lanix/Ilium' : 'inne' ,
'LG/K-200' : 'inne' ,
'line' : 'inne' ,
'M4Tel/M4' : 'inne' ,
'maxthon' : 'inne' ,
'Microsoft/Windows' : 'inne' ,
'mobile' : 'inne' ,
'mobile safari 10.0' : 'safari' ,
'mobile safari 11.0' : 'safari' ,
'mobile safari 8.0' : 'safari' ,
'mobile safari 9.0' : 'safari' ,
'mobile safari generic' : 'safari' ,
'mobile safari ui webview' : 'safari' ,
'Mozilla/Firefox' : 'firefox' ,
'Nokia/Lumia' : 'inne' ,
'opera' : 'opera' ,
'opera 49.0' : 'opera' ,
'opera 51.0' : 'opera' ,
'opera 52.0' : 'opera' ,
'opera 53.0' : 'opera' ,
'opera generic' : 'opera' ,
'other' : 'inne' ,
'palemoon' : 'inne' ,
'puffin' : 'inne' ,
'safari' : 'safari' ,
'safari 10.0' : 'safari' ,
'safari 11.0' : 'safari' ,
'safari 9.0' : 'safari' ,
'safari generic' : 'safari' ,
'samsung' : 'samsung' ,
'samsung browser 3.3' : 'samsung' ,
'samsung browser 4.0' : 'samsung' ,
'samsung browser 4.2' : 'samsung' ,
'samsung browser 5.2' : 'samsung' ,
'samsung browser 5.4' : 'samsung' ,
'samsung browser 6.4' : 'samsung' ,
'samsung browser 7.0' : 'samsung' ,
'samsung browser generic' : 'samsung' ,
'Samsung/SCH' : 'samsung' ,
'Samsung/SM-G531H' : 'samsung' ,
'Samsung/SM-G532M' : 'samsung' ,
'seamonkey' : 'inne' ,
'silk' : 'inne' ,
'waterfox' : 'inne' ,
'ZTE/Blade' : 'inne' ,
'samsung browser 6.2' : 'samsung'}, inplace=True)

df['P_emaildomain'].replace({'aim.com' :  'inne' ,
 'anonymous.com' :  'anonymous' ,
 'aol.com' :  'aol' ,
 'att.net' :  'inne' ,
 'bellsouth.net' :  'inne' ,
 'cableone.net' :  'inne' ,
 'centurylink.net' :  'inne' ,
 'cfl.rr.com' :  'inne' ,
 'charter.net' :  'inne' ,
 'comcast.net' :  'inne' ,
 'cox.net' :  'inne' ,
 'earthlink.net' :  'inne' ,
 'embarqmail.com' :  'inne' ,
 'frontier.com' :  'frontier' ,
 'frontiernet.net' :  'frontier' ,
 'gmail' :  'gmail' ,
 'gmail.com' :  'gmail' ,
 'gmx.de' :  'inne' ,
 'hotmail.co.uk' :  'hotmail' ,
 'hotmail.com' :  'hotmail' ,
 'hotmail.de' :  'hotmail' ,
 'hotmail.es' :  'hotmail' ,
 'hotmail.fr' :  'hotmail' ,
 'icloud.com' :  'inne' ,
 'juno.com' :  'inne' ,
 'live.com' :  'live' ,
 'live.com.mx' :  'live' ,
 'live.fr' :  'live' ,
 'mac.com' :  'inne' ,
 'mail.com' :  'inne' ,
 'me.com' :  'inne' ,
 'msn.com' :  'msn' ,
 'netzero.com' :  'netzero' ,
 'netzero.net' :  'netzero' ,
 'optonline.net' :  'inne' ,
 'outlook.com' :  'outlook' ,
 'outlook.es' :  'outlook' ,
 'prodigy.net.mx' :  'inne' ,
 'protonmail.com' :  'inne' ,
 'ptd.net' :  'inne' ,
 'q.com' :  'inne' ,
 'roadrunner.com' :  'inne' ,
 'rocketmail.com' :  'inne' ,
 'sbcglobal.net' :  'inne' ,
 'sc.rr.com' :  'inne' ,
 'servicios-ta.com' :  'inne' ,
 'suddenlink.net' :  'inne' ,
 'twc.com' :  'inne' ,
 'verizon.net' :  'inne' ,
 'web.de' :  'inne' ,
 'windstream.net' :  'inne' ,
 'yahoo.co.jp' :  'yahoo' ,
 'yahoo.co.uk' :  'yahoo' ,
 'yahoo.com' :  'yahoo' ,
 'yahoo.com.mx' :  'yahoo' ,
 'yahoo.de' :  'yahoo' ,
 'yahoo.es' :  'yahoo' ,
 'yahoo.fr' :  'yahoo' ,
 'ymail.com' :  'inne' ,},inplace=True)

df['R_emaildomain'].replace({'aim.com' :  'inne' ,
 'anonymous.com' :  'anonymous' ,
 'aol.com' :  'aol' ,
 'att.net' :  'inne' ,
 'bellsouth.net' :  'inne' ,
 'cableone.net' :  'inne' ,
 'centurylink.net' :  'inne' ,
 'cfl.rr.com' :  'inne' ,
 'charter.net' :  'inne' ,
 'comcast.net' :  'inne' ,
 'cox.net' :  'inne' ,
 'earthlink.net' :  'inne' ,
 'embarqmail.com' :  'inne' ,
 'frontier.com' :  'frontier' ,
 'frontiernet.net' :  'frontier' ,
 'gmail' :  'gmail' ,
 'gmx.de' :  'inne' ,
 'hotmail.co.uk' :  'hotmail' ,
 'hotmail.com' :  'hotmail' ,
 'hotmail.de' :  'hotmail' ,
 'hotmail.es' :  'hotmail' ,
 'hotmail.fr' :  'hotmail' ,
 'icloud.com' :  'inne' ,
 'juno.com' :  'inne' ,
 'live.com' :  'live' ,
 'live.com.mx' :  'live' ,
 'live.fr' :  'live' ,
 'mac.com' :  'inne' ,
 'mail.com' :  'inne' ,
 'me.com' :  'inne' ,
 'msn.com' :  'msn' ,
 'netzero.com' :  'netzero' ,
 'netzero.net' :  'netzero' ,
 'optonline.net' :  'inne' ,
 'outlook.com' :  'outlook' ,
 'outlook.es' :  'outlook' ,
 'prodigy.net.mx' :  'inne' ,
 'protonmail.com' :  'inne' ,
 'ptd.net' :  'inne' ,
 'q.com' :  'inne' ,
 'roadrunner.com' :  'inne' ,
 'rocketmail.com' :  'inne' ,
 'sbcglobal.net' :  'inne' ,
 'sc.rr.com' :  'inne' ,
 'scranton.edu' :  'inne' ,
 'servicios-ta.com' :  'inne' ,
 'suddenlink.net' :  'inne' ,
 'twc.com' :  'inne' ,
 'verizon.net' :  'inne' ,
 'web.de' :  'inne' ,
 'windstream.net' :  'inne' ,
 'yahoo.co.jp' :  'yahoo' ,
 'yahoo.co.uk' :  'yahoo' ,
 'yahoo.com' :  'yahoo' ,
 'yahoo.com.mx' :  'yahoo' ,
 'yahoo.de' :  'yahoo' ,
 'yahoo.es' :  'yahoo' ,
 'yahoo.fr' :  'yahoo' ,
 'ymail.com' :  'inne' ,
 'gmail.com' :  'gmail' ,},inplace=True)


df['DeviceInfo'].replace({'0PAJ5':'INNE',
'0PJA2':'INNE',
'0PM92':'INNE',
'1016S':'INNE',
'2PQ93':'INNE',
'2PS64 Build/NRD90M':'INNE',
'2PYB2':'INNE',
'2PZC5':'INNE',
'4003A':'INNE',
'4009F':'INNE',
'4013M Build/KOT49H':'INNE',
'4027A Build/KOT49H':'INNE',
'4034E':'INNE',
'4034G':'INNE',
'4047A Build/NRD90M':'INNE',
'4047G Build/NRD90M':'INNE',
'47418':'INNE',
'5010G Build/MRA58K':'INNE',
'5010S Build/MRA58K':'INNE',
'5011A Build/NRD90M':'INNE',
'5012G Build/MRA58K':'INNE',
'5015A Build/LMY47I':'INNE',
'5017A':'INNE',
'5025G Build/LMY47I':'INNE',
'5042A':'INNE',
'5044A':'INNE',
'5045I':'INNE',
'5049W Build/NRD90M':'INNE',
'5051A Build/MMB29M':'INNE',
'5054N':'INNE',
'5054S Build/LMY47V':'INNE',
'5056A Build/MMB29M':'INNE',
'5056N':'INNE',
'5057M':'INNE',
'5080A Build/MRA58K':'INNE',
'5085B Build/MRA58K':'INNE',
'5095I Build/MRA58K':'INNE',
'6037B':'INNE',
'6039A Build/LRX22G':'INNE',
'6045I Build/LRX22G':'INNE',
'6055B':'INNE',
'7048A Build/LRX22G':'INNE',
'7055A Build/KVT49L':'INNE',
'7_Plus':'INNE',
'8050G Build/LMY47I':'INNE',
'8062 Build/MRA58K':'INNE',
'8080 Build/LRX21M':'INNE',
'831C':'INNE',
'9002A':'INNE',
'9003A Build/MRA58K':'INNE',
'9008A Build/NRD90M':'INNE',
'9022X':'INNE',
'916':'INNE',
'9203A Build/MRA58K':'INNE',
'A0001':'INNE',
'A0001 Build/MHC19Q':'INNE',
'A1-850':'INNE',
'A1601 Build/LMY47I':'INNE',
'A3-A20':'INNE',
'A37f':'INNE',
'A3_mini':'INNE',
'A463BG':'INNE',
'A466BG':'INNE',
'A5002':'INNE',
'A50C+':'INNE',
'A574BL Build/NMF26F':'INNE',
'A577VL':'INNE',
'A621R':'INNE',
'A9':'INNE',
'A952':'INNE',
'A96 Build/LMY47I':'INNE',
'A97':'INNE',
'AERIAL':'INNE',
'AERIAL Build/NRD90M':'INNE',
'AKUS':'INNE',
'ALCATEL':'INNE',
'ALCATEL ONE TOUCH 5036A Build/JDQ39':'INNE',
'ALCATEL ONE TOUCH 7040A Build/JDQ39':'INNE',
'ALCATEL ONE TOUCH 7042A Build/JDQ39':'INNE',
'ALCATEL ONE TOUCH 7047A Build/JDQ39':'INNE',
'ALE-L21 Build/HuaweiALE-L21':'INNE',
'ALE-L23 Build/HuaweiALE-L23':'INNE',
'ALP-L09 Build/HUAWEIALP-L09':'INNE',
'ALP-L09 Build/HUAWEIALP-L09S':'INNE',
'ALTER':'INNE',
'ALUMINI':'INNE',
'AM508':'INNE',
'ANE-LX3 Build/HUAWEIANE-LX3':'INNE',
'AOC_U706G':'INNE',
'ASTRO':'INNE',
'ASUS':'ASUS',
'ASUS_A001':'ASUS',
'ASUS_P00J':'ASUS',
'ASUS_X008D Build/NRD90M':'ASUS',
'ASUS_X008DC Build/NRD90M':'ASUS',
'ASUS_X00DD':'ASUS',
'ASUS_X00DDA':'ASUS',
'ASUS_X00HD Build/NMF26F':'ASUS',
'ASUS_X00ID':'ASUS',
'ASUS_X015D Build/NRD90M':'ASUS',
'ASUS_X018D':'ASUS',
'ASUS_Z00AD Build/LRX21V':'ASUS',
'ASUS_Z00ED':'ASUS',
'ASUS_Z00UD':'ASUS',
'ASUS_Z017D':'ASUS',
'ASUS_Z017DA':'ASUS',
'ASUS_Z01BDA':'ASUS',
'ASUS_Z01BDC':'ASUS',
'ASUS_Z01KD':'ASUS',
'ATT':'INNE',
'ATT-IE11':'INNE',
'AX1060':'INNE',
'AX1070':'INNE',
'AX705':'INNE',
'AX820 Build/MRA58K':'INNE',
'AX821 Build/MRA58K':'INNE',
'AX920':'INNE',
'AX921 Build/MRA58K':'INNE',
'Advance':'INNE',
'Alcatel':'INNE',
'Alcatel_4060A':'INNE',
'Alcatel_4060O Build/MMB29M':'INNE',
'Alcatel_5044R Build/NRD90M':'INNE',
'Alcatel_5054O':'INNE',
'Alcatel_5056O':'INNE',
'Alcatel_5098O Build/MMB29M':'INNE',
'Alumini3 Build/MRA58K':'INNE',
'Alumini3Plus':'INNE',
'Android':'INNE',
'Android 4.4.2':'INNE',
'Android 5.1':'INNE',
'Android 5.1.1':'INNE',
'Android 6.0':'INNE',
'Android 6.0.1':'INNE',
'Android 7.0':'INNE',
'Android 7.1.2':'INNE',
'Aquaris':'INNE',
'Aquaris U Plus Build/NMF26F':'INNE',
'Aquaris V Build/N2G47H':'INNE',
'Aquaris X Build/NMF26F':'INNE',
'Aquaris X5 Plus Build/NMF26F':'INNE',
'Aquaris_A4.5':'INNE',
'Archos':'INNE',
'Azumi_KINZO_A5_QL':'INNE',
'B1-750':'INNE',
'B1-790':'INNE',
'B1-810':'INNE',
'B3-A20':'INNE',
'B3-A40':'INNE',
'BAC-L03 Build/HUAWEIBAC-L03':'INNE',
'BAH-L09 Build/HUAWEIBAH-L09':'INNE',
'BBA100-1':'INNE',
'BBA100-2':'INNE',
'BBB100-1':'INNE',
'BBB100-2':'INNE',
'BBB100-3':'INNE',
'BG2-W09':'INNE',
'BLA-L09 Build/HUAWEIBLA-L09':'INNE',
'BLA-L29 Build/HUAWEIBLA-L29':'INNE',
'BLADE A520 Build/NRD90M':'INNE',
'BLADE A602 Build/MRA58K':'INNE',
'BLADE L7 Build/MRA58K':'INNE',
'BLADE V7 Build/MRA58K':'INNE',
'BLADE V8 Build/NRD90M':'INNE',
'BLADE V8 SE Build/NRD90M':'INNE',
'BLADE V8Q Build/N2G47H':'INNE',
'BLL-L23 Build/HUAWEIBLL-L23':'INNE',
'BLN-L21 Build/HONORBLN-L21':'INNE',
'BLN-L24 Build/HONORBLN-L24':'INNE',
'BLU':'INNE',
'BLU ENERGY X PLUS Build/LRX21M':'INNE',
'BLU LIFE XL Build/L050U':'INNE',
'BLU STUDIO C 5+5 Build/LRX21M':'INNE',
'BND-L21 Build/HONORBND-L21':'INNE',
'BND-L34':'INNE',
'BNTV400':'INNE',
'BOIE9':'INNE',
'BV6000':'INNE',
'BV7000':'INNE',
'BV8000Pro':'INNE',
'Beat':'INNE',
'Blade':'INNE',
'Blade A460 Build/LMY47O':'INNE',
'Blade A465 Build/LMY47D':'INNE',
'Blade A475 Build/LMY47D':'INNE',
'Blade A510 Build/MRA58K':'INNE',
'Blade L2 Plus Build/KOT49H':'INNE',
'Blade L3 Build/KOT49H':'INNE',
'Blade L5 Build/LMY47I':'INNE',
'Blade V580 Build/LMY47D':'INNE',
'Blade V6 Build/LRX22G':'INNE',
'Blade V6 Max Build/MRA58K':'INNE',
'Blade V6 Plus Build/MRA58K':'INNE',
'Bolt':'INNE',
'Build/KOT49H':'INNE',
'Build/OPM1.171019.011':'INNE',
'Build/OPR1.170623.032':'INNE',
'Build/OPR6.170623.013':'INNE',
'C1904':'INNE',
'C2104':'INNE',
'C6603':'INNE',
'C6743 Build/LMY47V':'INNE',
'C6903':'INNE',
'C6906':'INNE',
'C6906 Build/14.6.A.1.236':'INNE',
'CAM-L03 Build/HUAWEICAM-L03':'INNE',
'CAM-L23':'INNE',
'CHC-U03 Build/HuaweiCHC-U03':'INNE',
'CLT-L09':'INNE',
'COVET Build/NRD90M':'INNE',
'CPH1607':'INNE',
'CPH1701':'INNE',
'CPH1723':'INNE',
'CRO-L03 Build/HUAWEICRO-L03':'INNE',
'Coolpad':'INNE',
'D2306':'INNE',
'D2306 Build/18.6.A.0.182':'INNE',
'D2406':'INNE',
'D5106':'INNE',
'D5306':'INNE',
'D5306 Build/19.4.A.0.182':'INNE',
'D5316':'INNE',
'D5316 Build/19.4.A.0.182':'INNE',
'D5503':'INNE',
'D5803 Build/23.5.A.1.291':'INNE',
'D6503':'INNE',
'D6603':'INNE',
'D6603 Build/23.5.A.1.291':'INNE',
'D6708':'INNE',
'DASH':'INNE',
'DLI-L22 Build/HONORDLI-L22':'INNE',
'DOMOS':'INNE',
'DT0704K08':'INNE',
'DUK-AL20':'INNE',
'Dash':'INNE',
'Dream':'INNE',
'E2006':'INNE',
'E2104':'INNE',
'E2104 Build/24.0.A.5.14':'INNE',
'E2303':'INNE',
'E2306 Build/26.1.A.3.111':'INNE',
'E2306 Build/26.3.A.1.33':'INNE',
'E501':'INNE',
'E5306':'INNE',
'E5306 Build/27.3.A.0.129':'INNE',
'E5306 Build/27.3.A.0.165':'INNE',
'E5506':'INNE',
'E5506 Build/29.1.A.0.101':'INNE',
'E5506 Build/29.2.A.0.166':'INNE',
'E5606':'INNE',
'E5606 Build/30.2.A.1.21':'INNE',
'E5803':'INNE',
'E5803 Build/32.4.A.1.54':'INNE',
'E5823':'INNE',
'E5823 Build/32.4.A.1.54':'INNE',
'E6553':'INNE',
'E6603':'INNE',
'E6603 Build/32.4.A.1.54':'INNE',
'E6633':'INNE',
'E6653 Build/32.4.A.1.54':'INNE',
'E6683':'INNE',
'E6790TM':'INNE',
'E6810':'INNE',
'E6810 Build/5.320VZ.03.r':'INNE',
'E6833':'INNE',
'E6853':'INNE',
'E6853 Build/32.4.A.1.54':'INNE',
'E8QP':'INNE',
'EGO':'INNE',
'EML-L29 Build/HUAWEIEML-L29':'INNE',
'EVA-L09 Build/HUAWEIEVA-L09':'INNE',
'EVA-L19 Build/HUAWEIEVA-L19':'INNE',
'Edison':'INNE',
'Energy X 2 Build/E050L':'INNE',
'F1f Build/LMY47V':'INNE',
'F3111 Build/33.3.A.1.115':'INNE',
'F3111 Build/33.3.A.1.97':'INNE',
'F3113':'INNE',
'F3113 Build/33.2.A.3.81':'INNE',
'F3113 Build/33.2.A.4.70':'INNE',
'F3113 Build/33.3.A.1.97':'INNE',
'F3213':'INNE',
'F3213 Build/36.0.A.2.146':'INNE',
'F3213 Build/36.1.A.1.86':'INNE',
'F3311':'INNE',
'F3313':'INNE',
'F3313 Build/37.0.A.2.108':'INNE',
'F3313 Build/37.0.A.2.248':'INNE',
'F5121':'INNE',
'F5121 Build/34.3.A.0.228':'INNE',
'F5121 Build/34.3.A.0.238':'INNE',
'F5121 Build/34.3.A.0.252':'INNE',
'F5121 Build/34.4.A.2.19':'INNE',
'F5122':'INNE',
'F5321':'INNE',
'F5321 Build/34.2.A.2.47':'INNE',
'F5321 Build/34.3.A.0.238':'INNE',
'F80 PIABELLA Build/MRA58K':'INNE',
"F80'S+":'INNE',
'F8131':'INNE',
'F8331':'INNE',
'F8331 Build/41.2.A.7.76':'INNE',
'F8332':'INNE',
'FEVER':'INNE',
'FIG-LX3 Build/HUAWEIFIG-LX3':'INNE',
'FP2':'INNE',
'FRD-L04 Build/HUAWEIFRD-L04':'INNE',
'FRD-L09 Build/HUAWEIFRD-L09':'INNE',
'FRD-L14 Build/HUAWEIFRD-L14':'INNE',
'FTJ152D':'INNE',
'Fractal':'INNE',
'Fusion5_u7':'INNE',
'G25524K':'INNE',
'G3123':'INNE',
'G3123 Build/40.0.A.6.135':'INNE',
'G3123 Build/40.0.A.6.175':'INNE',
'G3123 Build/40.0.A.6.189':'INNE',
'G3223':'INNE',
'G3223 Build/42.0.A.4.101':'INNE',
'G3223 Build/42.0.A.4.167':'INNE',
'G3313':'INNE',
'G3313 Build/43.0.A.5.79':'INNE',
'G3313 Build/43.0.A.7.25':'INNE',
'G3423':'INNE',
'G527-U081':'INNE',
'G620S-L03':'INNE',
'G630-U251':'INNE',
'G8141':'INNE',
'G8141 Build/47.1.A.5.51':'INNE',
'G8142':'INNE',
'G8341':'INNE',
'GRACE':'INNE',
'GRANT':'INNE',
'GT-I8190L Build/JZO54K':'INNE',
'GT-I8190N':'INNE',
'GT-I8200N':'INNE',
'GT-I9060L Build/JDQ39':'INNE',
'GT-I9060M Build/KTU84P':'INNE',
'GT-I9195I':'INNE',
'GT-I9195L':'INNE',
'GT-I9300':'INNE',
'GT-I9500':'INNE',
'GT-I9505 Build/LRX22C':'INNE',
'GT-I9506':'INNE',
'GT-I9515':'INNE',
'GT-N5110':'INNE',
'GT-N5110 Build/JDQ39':'INNE',
'GT-N7100':'INNE',
'GT-N8000':'INNE',
'GT-N8010':'INNE',
'GT-P3100':'INNE',
'GT-P5110':'INNE',
'GT-P5113':'INNE',
'GT-P5210 Build/JDQ39':'INNE',
'GT-P5210 Build/KOT49H':'INNE',
'GT-S5310L':'INNE',
'GT-S7275B':'INNE',
'GT-S7390':'INNE',
'GT-S7580L Build/JDQ39':'INNE',
'GT-S7582':'INNE',
'GT-S7582L':'INNE',
'Gigaset':'INNE',
'Grand':'INNE',
'Grand2c':'INNE',
'Gravity Build/NRD90M':'INNE',
'H1611':'INNE',
'H1711 Build/HUAWEIH1711':'INNE',
'H3321':'INNE',
'H550':'INNE',
'HELIO':'INNE',
'HIGHWAY':'INNE',
'HP':'INNE',
'HT0701A16':'INNE',
'HT0703K16':'INNE',
'HTC':'HTC',
'HTC 10 Build/NRD90M':'HTC',
'HTC Desire 10 lifestyle Build/MMB29M':'HTC',
'HTC Desire 510 Build/KOT49H':'HTC',
'HTC Desire 526G Build/KOT49H':'HTC',
'HTC Desire 530 Build/MMB29M':'HTC',
'HTC Desire 626s Build/LMY47O':'HTC',
'HTC Desire 650 Build/MMB29M':'HTC',
'HTC One A9 Build/NRD90M':'HTC',
'HTC One A9s Build/MRA58K':'HTC',
'HTC One Build/LRX22G':'HTC',
'HTC One M9 Build/NRD90M':'HTC',
'HTC One mini Build/KOT49H':'HTC',
'HTC One_M8 Build/MRA58K':'HTC',
'HTC U11 Build/NMF26X':'HTC',
'HTC U11 Build/OPR6.170623.013':'HTC',
'HTC6500LVW':'HTC',
'HTC6525LVW':'HTC',
'HTC6535LVW':'HTC',
'HTC6545LVW':'HTC',
'HTCD100LVWPP':'HTC',
'HTCD160LVWPP':'HTC',
'HTCD200LVW':'HTC',
'HTC_D10i':'HTC',
'HTC_Desire_820':'HTC',
'HTC_One':'HTC',
'HTC_One_M8/4.28.502.2':'HTC',
'HTC_One_M8s/2.12.111.1':'HTC',
'HUAWEI':'HUAWEI',
'HUAWEI Build/MMB28B':'HUAWEI',
'HUAWEI CAN-L01 Build/HUAWEICAN-L01':'HUAWEI',
'HUAWEI CAN-L11 Build/HUAWEICAN-L11':'HUAWEI',
'HUAWEI CUN-L03 Build/HUAWEICUN-L03':'HUAWEI',
'HUAWEI G7-L03 Build/HuaweiG7-L03':'HUAWEI',
'HUAWEI GRA-L09 Build/HUAWEIGRA-L09':'HUAWEI',
'HUAWEI LUA-U23 Build/HUAWEILUA-U23':'HUAWEI',
'HUAWEI LYO-L21 Build/HUAWEILYO-L21':'HUAWEI',
'HUAWEI M2-801W Build/HUAWEIM2-801W':'HUAWEI',
'HUAWEI NXT-L09 Build/HUAWEINXT-L09':'HUAWEI',
'HUAWEI RIO-L03 Build/HUAWEIRIO-L03':'HUAWEI',
'HUAWEI TAG-L13 Build/HUAWEITAG-L13':'HUAWEI',
'HUAWEI VNS-L21 Build/HUAWEIVNS-L21':'HUAWEI',
'HUAWEI VNS-L23 Build/HUAWEIVNS-L23':'HUAWEI',
'HUAWEI VNS-L31 Build/HUAWEIVNS-L31':'HUAWEI',
'HUAWEI VNS-L53 Build/HUAWEIVNS-L53':'HUAWEI',
'HUAWEI Y360-U23 Build/HUAWEIY360-U23':'HUAWEI',
'HUAWEI Y520-U03 Build/HUAWEIY520-U03':'HUAWEI',
'HUAWEI Y560-L03 Build/HUAWEIY560-L03':'HUAWEI',
'HUAWEI Y625-U13 Build/HUAWEIY625-U13':'HUAWEI',
'Helix':'INNE',
'Hisense':'HISENSE',
'Hisense E51 Build/LMY47V':'HISENSE',
'Hisense F102 Build/NRD90M':'HISENSE',
'Hisense F20 Build/MMB29M':'HISENSE',
'Hisense F23 Build/NRD90M':'HISENSE',
'Hisense F24 Build/NRD90M':'HISENSE',
'Hisense F32 Build/NMF26F':'HISENSE',
'Hisense F8 MINI Build/NRD90M':'HISENSE',
'Hisense L675 Build/MRA58K':'HISENSE',
'Hisense L675 PRO Build/NRD90M':'HISENSE',
'Hisense T963 Build/MRA58K':'HISENSE',
'Hisense U963 Build/MRA58K':'HISENSE',
'ICON':'INNE',
'ILIUM':'INNE',
'IO':'INNE',
'IdeaTab':'INNE',
'IdeaTabA1000-F':'INNE',
'IdeaTabA2109A':'INNE',
'Ilium':'INNE',
'Ilium L1000 Build/LRX22G':'INNE',
'Ilium L1120 Build/NRD90M':'INNE',
'Ilium L610 Build/MRA58K':'INNE',
'Ilium L620 Build/NRD90M':'INNE',
'Ilium L910 Build/MRA58K':'INNE',
'Ilium L950 Build/KTU84P':'INNE',
'Ilium LT500 Build/LMY47O':'INNE',
'Ilium LT510 Build/MRA58K':'INNE',
'Ilium LT520 Build/NRD90M':'INNE',
'Ilium Pad T7X Build/LMY47I':'INNE',
'Ilium X210 Build/LMY47I':'INNE',
'Ilium X220 Build/MRA58K':'INNE',
'Ilium X510 Build/MRA58K':'INNE',
'Ilium X520 Build/NRD90M':'INNE',
'Ilium X710 Build/MRA58K':'INNE',
'Infinit':'INNE',
'Infinix':'INNE',
'Intel':'INNE',
'Joy':'INNE',
'K10':'INNE',
'K88':'INNE',
'K88 Build/MMB29M':'INNE',
'K90U':'INNE',
'K92':'INNE',
'KFAPWI Build/KTU84M':'INNE',
'KFASWI Build/LVY48F':'INNE',
'KFAUWI Build/LVY48F':'INNE',
'KFDOWI Build/LVY48F':'INNE',
'KFFOWI Build/LVY48F':'INNE',
'KFGIWI Build/LVY48F':'INNE',
'KFJWI':'INNE',
'KFMEWI':'INNE',
'KFSAWI':'INNE',
'KFSOWI':'INNE',
'KFSUWI Build/LVY48F':'INNE',
'KFTBWI Build/LVY48F':'INNE',
'KFTHWI Build/KTU84M':'INNE',
'KFTT Build/IML74K':'INNE',
'KIW-L24':'INNE',
'KYOCERA-C6742A Build/LMY47V':'INNE',
'KYY22':'INNE',
'Kylin':'INNE',
'LAVA_A3':'INNE',
'LDN-LX3 Build/HUAWEILDN-LX3':'INNE',
'LEX829':'INNE',
'LG-D213':'LG',
'LG-D320':'LG',
'LG-D320 Build/KOT49I.V10a':'LG',
'LG-D331':'LG',
'LG-D331 Build/LRX22G':'LG',
'LG-D373':'LG',
'LG-D373 Build/KOT49I.V10a':'LG',
'LG-D400':'LG',
'LG-D625':'LG',
'LG-D680':'LG',
'LG-D680 Build/KOT49I':'LG',
'LG-D681':'LG',
'LG-D693n':'LG',
'LG-D693n Build/KOT49I.V10a':'LG',
'LG-D693n Build/LRX22G':'LG',
'LG-D722':'LG',
'LG-D725':'LG',
'LG-D802':'LG',
'LG-D850':'LG',
'LG-D851':'LG',
'LG-D855':'LG',
'LG-D855 Build/LRX21R':'LG',
'LG-D959':'LG',
'LG-E450f':'LG',
'LG-E975':'LG',
'LG-E980h':'LG',
'LG-F400K':'LG',
'LG-H221':'LG',
'LG-H320 Build/LRX21Y':'LG',
'LG-H340AR':'LG',
'LG-H343':'LG',
'LG-H345':'LG',
'LG-H420 Build/LRX21Y':'LG',
'LG-H443/H44312g':'LG',
'LG-H500 Build/LRX21Y':'LG',
'LG-H520':'LG',
'LG-H525n Build/MRA58K':'LG',
'LG-H540':'LG',
'LG-H542 Build/LRX22G':'LG',
'LG-H542 Build/MRA58K':'LG',
'LG-H631':'LG',
'LG-H650 Build/LMY47V':'LG',
'LG-H650 Build/MRA58K':'LG',
'LG-H700 Build/NRD90U':'LG',
'LG-H735 Build/LMY47V':'LG',
'LG-H810':'LG',
'LG-H810/H81021z':'LG',
'LG-H810/H81022f':'LG',
'LG-H811 Build/MRA58K':'LG',
'LG-H812':'LG',
'LG-H815':'LG',
'LG-H815 Build/MRA58K':'LG',
'LG-H820':'LG',
'LG-H820 Build/NRD90U':'LG',
'LG-H830':'LG',
'LG-H830 Build/NRD90U':'LG',
'LG-H831 Build/NRD90U':'LG',
'LG-H840 Build/MMB29M':'LG',
'LG-H840 Build/NRD90U':'LG',
'LG-H850':'LG',
'LG-H850 Build/MMB29M':'LG',
'LG-H870 Build/NRD90U':'LG',
'LG-H870DS Build/NRD90U':'LG',
'LG-H871':'LG',
'LG-H872 Build/NRD90U':'LG',
'LG-H900/H90022b':'LG',
'LG-H901':'LG',
'LG-H910 Build/NRD90M':'LG',
'LG-H918 Build/NRD90M':'LG',
'LG-H931':'LG',
'LG-H932':'LG',
'LG-H933':'LG',
'LG-H960':'LG',
'LG-H990 Build/NRD90M':'LG',
'LG-K200 Build/MXB48T':'LG',
'LG-K212':'LG',
'LG-K220 Build/MXB48T':'LG',
'LG-K240 Build/MXB48T':'LG',
'LG-K330':'LG',
'LG-K350':'LG',
'LG-K371':'LG',
'LG-K373':'LG',
'LG-K410 Build/LRX22G':'LG',
'LG-K420':'LG',
'LG-K428 Build/MMB29M':'LG',
'LG-K428 Build/NRD90U':'LG',
'LG-K430 Build/MRA58K':'LG',
'LG-K450 Build/MXB48T':'LG',
'LG-K500 Build/MMB29M':'LG',
'LG-K530 Build/MMB29M':'LG',
'LG-K530 Build/NRD90U':'LG',
'LG-K540 Build/MMB29M':'LG',
'LG-K550':'LG',
'LG-K550 Build/NRD90U':'LG',
'LG-K580 Build/MRA58K':'LG',
'LG-LG870':'LG',
'LG-LK460':'LG',
'LG-LS777 Build/NRD90U':'LG',
'LG-LS993 Build/NRD90U':'LG',
'LG-LS995':'LG',
'LG-LS997 Build/NRD90M':'LG',
'LG-LS998':'LG',
'LG-M150':'LG',
'LG-M153 Build/MXB48T':'LG',
'LG-M154':'LG',
'LG-M200 Build/NRD90U':'LG',
'LG-M210 Build/NRD90U':'LG',
'LG-M250 Build/NRD90U':'LG',
'LG-M255':'LG',
'LG-M257':'LG',
'LG-M320 Build/NRD90U':'LG',
'LG-M322':'LG',
'LG-M327 Build/NRD90U':'LG',
'LG-M400 Build/NRD90U':'LG',
'LG-M430 Build/NRD90U':'LG',
'LG-M700 Build/NMF26X':'LG',
'LG-M710 Build/NRD90U':'LG',
'LG-P708g':'LG',
'LG-P714':'LG',
'LG-SP200':'LG',
'LG-SP320':'LG',
'LG-TP260 Build/NRD90U':'LG',
'LG-TP450 Build/NRD90U':'LG',
'LG-V410':'LG',
'LG-V410/V41020c':'LG',
'LG-V495':'LG',
'LG-V495/V49520l':'LG',
'LG-V496':'LG',
'LG-V500':'LG',
'LG-V520':'LG',
'LG-V521':'LG',
'LG-V522':'LG',
'LG-V700':'LG',
'LG-V930':'LG',
'LG-X165g Build/LRX21M':'LG',
'LG-X180g Build/LMY47I':'LG',
'LG-X210 Build/LMY47I':'LG',
'LG-X220 Build/LMY47I':'LG',
'LG-X230 Build/MRA58K':'LG',
'LG-X240 Build/MRA58K':'LG',
'LGL163BL':'LG',
'LGL164VL Build/NRD90U':'LG',
'LGL33L/V100':'LG',
'LGL41C':'LG',
'LGL52VL Build/LMY47V':'LG',
'LGL57BL':'LG',
'LGL58VL':'LG',
'LGL62VL':'LG',
'LGL83BL':'LG',
'LGL84VL Build/NRD90U':'LG',
'LGLK430':'LG',
'LGLS665 Build/LMY47V':'LG',
'LGLS675 Build/LMY47V':'LG',
'LGLS676 Build/MXB48T':'LG',
'LGLS751':'LG',
'LGLS755':'LG',
'LGLS770':'LG',
'LGLS775 Build/MMB29M':'LG',
'LGLS775 Build/NRD90U':'LG',
'LGLS990':'LG',
'LGLS991':'LG',
'LGLS992':'LG',
'LGMP260 Build/NRD90U':'LG',
'LGMP450 Build/NRD90U':'LG',
'LGMS210 Build/NRD90U':'LG',
'LGMS323':'LG',
'LGMS330 Build/LMY47V':'LG',
'LGMS345':'LG',
'LGMS395':'LG',
'LGMS428':'LG',
'LGMS550 Build/MXB48T':'LG',
'LGMS550 Build/NRD90U':'LG',
'LGMS631':'LG',
'LGMS631 Build/MRA58K':'LG',
'LGUS215 Build/NRD90U':'LG',
'LGUS990':'LG',
'LGUS991':'LG',
'LGUS992':'LG',
'LIMIT':'INNE',
'LM-X210(G':'INNE',
'LOGIC':'INNE',
'LS5':'INNE',
'LT22i Build/6.2.A.1.100':'INNE',
'LT30p':'INNE',
'Le':'INNE',
'Le X520 Build/IEXCNFN5902303111S':'INNE',
'Lenovo':'LENOVO',
'Lenovo A2016b30 Build/MRA58K':'LENOVO',
'Lenovo A6020l37 Build/LMY47V':'LENOVO',
'Lenovo K33b36 Build/MMB29M':'LENOVO',
'Lenovo K33b36 Build/NRD90N':'LENOVO',
'Lenovo PB1-750M Build/S100':'LENOVO',
'Lenovo PB2-650Y Build/MRA58K':'LENOVO',
'Lenovo PB2-670Y Build/MRA58K':'LENOVO',
'Lenovo TAB 2 A7-30GC Build/KOT49H':'LENOVO',
'Lenovo TB-7703X Build/S100':'LENOVO',
'Lenovo TB-X103F Build/LenovoTB-X103F':'LENOVO',
'Lenovo TB2-X30F Build/LenovoTB2-X30F':'LENOVO',
'Lenovo TB3-710F Build/LRX21M':'LENOVO',
'Lenovo TB3-710I Build/LMY47I':'LENOVO',
'Lenovo YT3-850F Build/MMB29M':'LENOVO',
'Lenovo YT3-850M Build/MMB29M':'LENOVO',
'Lenovo YT3-X50F Build/MMB29M':'LENOVO',
'Lenovo-A6020l36 Build/LMY47V':'LENOVO',
'LenovoA3300-GV Build/JDQ39':'LENOVO',
'Linux':'LINUX',
'Linux i686':'LINUX',
'Linux x86_64':'LINUX',
'M10/Q1010':'INNE',
'M4':'INNE',
'M4 SS4450 Build/MRA58K':'INNE',
'M4 SS4451 Build/LMY47D':'INNE',
'M4 SS4452 Build/LMY47V':'INNE',
'M4 SS4453 Build/MMB29M':'INNE',
'M4 SS4456 Build/LMY47V':'INNE',
'M4 SS4457 Build/MRA58K':'INNE',
'M4 SS4457-R Build/NRD90M':'INNE',
'M4 SS4458 Build/MMB29M':'INNE',
'M431':'INNE',
'MAGNO':'INNE',
'MALC':'INNE',
'MAMI':'INNE',
'MDDRJS':'INNE',
'ME173X':'INNE',
'ME301T':'INNE',
'MHA-L09 Build/HUAWEIMHA-L09':'INNE',
'MHA-L29 Build/HUAWEIMHA-L29':'INNE',
'MI':'INNE',
'MI MAX 2 Build/NMF26F':'INNE',
'MOT-A6020l37 Build/LMY47V':'INNE',
'MTT':'INNE',
'MYA-L03 Build/HUAWEIMYA-L03':'INNE',
'MYA-L11':'INNE',
'MYA-L13 Build/HUAWEIMYA-L13':'INNE',
'MYA-L23':'INNE',
'MacOS':'INNE',
'Max':'INNE',
'Mi':'INNE',
'Mi A1 Build/N2G47H':'INNE',
'Mi A1 Build/OPR1.170623.026':'INNE',
'Microsoft':'WINDOWS',
'Minion_Tab':'INNE',
'Mobiistar_LAI_Yuna_X':'INNE',
'Moto':'MOTO',
'Moto C Build/NRD90M.046':'MOTO',
'Moto C Build/NRD90M.050':'MOTO',
'Moto C Build/NRD90M.054':'MOTO',
'Moto C Build/NRD90M.057':'MOTO',
'Moto C Build/NRD90M.063':'MOTO',
'Moto C Build/NRD90M.070':'MOTO',
'Moto C Plus Build/NRD90M.05.022':'MOTO',
'Moto C Plus Build/NRD90M.05.034':'MOTO',
'Moto E (4) Build/NCQ26.69-56':'MOTO',
'Moto E (4) Build/NDQS26.69-23-2-3':'MOTO',
'Moto E (4) Build/NDQS26.69-64-2':'MOTO',
'Moto E (4) Build/NMA26.42-11-3':'MOTO',
'Moto E (4) Build/NMA26.42-19':'MOTO',
'Moto E (4) Build/NMA26.42-69':'MOTO',
'Moto E (4) Plus Build/NMA26.42-11-3':'MOTO',
'Moto E (4) Plus Build/NMA26.42-142':'MOTO',
'Moto E (4) Plus Build/NMA26.42-152':'MOTO',
'Moto E (4) Plus Build/NMA26.42-69':'MOTO',
'Moto G (4) Build/NPJ25.93-14':'MOTO',
'Moto G (4) Build/NPJ25.93-14.5':'MOTO',
'Moto G (4) Build/NPJ25.93-14.7':'MOTO',
'Moto G (4) Build/NPJS25.93-14-10':'MOTO',
'Moto G (4) Build/NPJS25.93-14-13':'MOTO',
'Moto G (4) Build/NPJS25.93-14-15':'MOTO',
'Moto G (4) Build/NPJS25.93-14-18':'MOTO',
'Moto G (4) Build/NPJS25.93-14-8':'MOTO',
'Moto G (4) Build/NPJS25.93-14-8.1-4':'MOTO',
'Moto G (5) Build/NPP25.137-15':'MOTO',
'Moto G (5) Build/NPP25.137-33':'MOTO',
'Moto G (5) Build/NPP25.137-38':'MOTO',
'Moto G (5) Build/NPP25.137-72':'MOTO',
'Moto G (5) Build/NPP25.137-82':'MOTO',
'Moto G (5) Build/NPP25.137-93':'MOTO',
'Moto G (5) Build/NPPS25.137-15-11':'MOTO',
'Moto G (5) Build/NPPS25.137-93-4':'MOTO',
'Moto G (5) Build/NPPS25.137-93-8':'MOTO',
'Moto G (5) Plus Build/NPN25.137-15':'MOTO',
'Moto G (5) Plus Build/NPN25.137-72':'MOTO',
'Moto G (5) Plus Build/NPN25.137-82':'MOTO',
'Moto G (5) Plus Build/NPN25.137-83':'MOTO',
'Moto G (5) Plus Build/NPN25.137-92':'MOTO',
'Moto G (5) Plus Build/NPNS25.137-15-11':'MOTO',
'Moto G (5) Plus Build/NPNS25.137-92-10':'MOTO',
'Moto G (5) Plus Build/NPNS25.137-92-4':'MOTO',
'Moto G (5) Plus Build/NPNS25.137-92-8':'MOTO',
'Moto G (5) Plus Build/NPNS25.137-93-8':'MOTO',
'Moto G (5S':'MOTO',
'Moto G Play Build/MPIS24.241-15.3-26':'MOTO',
'Moto G Play Build/MPIS24.241-15.3-7':'MOTO',
'Moto G Play Build/NJH47F':'MOTO',
'Moto G Play Build/NPI26.48-36':'MOTO',
'Moto G Play Build/NPIS26.48-36-2':'MOTO',
'Moto G Play Build/NPIS26.48-36-5':'MOTO',
'Moto X Play Build/NPD26.48-24-1':'MOTO',
'Moto Z (2':'MOTO',
'Moto Z2 Play Build/NPS26.118-19':'MOTO',
'Moto Z2 Play Build/NPS26.74-16-1':'MOTO',
'Moto Z2 Play Build/NPSS26.118-19-11':'MOTO',
'Moto Z2 Play Build/NPSS26.118-19-14':'MOTO',
'Moto Z2 Play Build/NPSS26.118-19-4':'MOTO',
'Moto Z2 Play Build/NPSS26.118-19-6':'MOTO',
'MotoE2 Build/LPCS23.13-56-5':'MOTO',
'MotoE2(4G-LTE':'MOTO',
'MotoG3':'MOTO',
'MotoG3 Build/MPI24.65-25':'MOTO',
'MotoG3 Build/MPI24.65-25.1':'MOTO',
'MotoG3 Build/MPI24.65-33.1-2':'MOTO',
'MotoG3 Build/MPIS24.107-55-2-17':'MOTO',
'MotoG3 Build/MPIS24.65-25.1-19':'MOTO',
'MotoG3 Build/MPIS24.65-33.1-2-16':'MOTO',
'MotoG3-TE':'MOTO',
'MotoG3-TE Build/MPD24.65-33':'MOTO',
'MotoG3-TE Build/MPDS24.65-33-1-3':'MOTO',
'MotoG3-TE Build/MPDS24.65-33-1-30':'MOTO',
'N817':'NOKIA',
'N9136':'NOKIA',
'N9560 Build/NMF26F':'NOKIA',
'NEM-L51 Build/HONORNEM-L51':'NOKIA',
'NOKIA':'NOKIA',
'NX16A8116KP':'NEXUS',
'NX521J':'NEXUS',
'NX785QC8G':'NEXUS',
'NXA116QC164':'NEXUS',
'NXA8QC116':'NEXUS',
'NYX_A1':'NEXUS',
'Neffos C5 Build/LMY47D':'NEXUS',
'Neffos X1 Max Build/NRD90M':'NEXUS',
'NetHelper70':'NEXUS',
'Nexus':'NEXUS',
'Nexus 5 Build/M4B30Z':'NEXUS',
'Nexus 5X Build/OPM3.171019.013':'NEXUS',
'Nexus 5X Build/OPR4.170623.006':'NEXUS',
'Nexus 6 Build/MOB30M':'NEXUS',
'Nexus 6 Build/N6F27M':'NEXUS',
'Nexus 6P Build/OPR5.170623.011':'NEXUS',
'Nexus 6P Build/OPR5.170623.014':'NEXUS',
'Northwell':'INNE',
'O1':'INNE',
'ONE':'INNE',
'ONE A2003 Build/MMB29M':'INNE',
'ONE A2005 Build/MMB29M':'INNE',
'ONE TOUCH 4016A Build/JDQ39':'INNE',
'ONE TOUCH 4033A Build/JDQ39':'INNE',
'ONEPLUS':'INNE',
'ONEPLUS A5000 Build/NMF26X':'INNE',
'ONEPLUS A5010 Build/OPM1.171019.011':'INNE',
'ORION':'INNE',
'Origins':'INNE',
'P008 Build/NRD90M':'INNE',
'P00A':'INNE',
'P00C':'INNE',
'P01M':'INNE',
'P027':'INNE',
'P4526A Build/NRD90M':'INNE',
'P5006A':'INNE',
'P5006A Build/NRD90M':'INNE',
'P5026A':'INNE',
'P5046A':'INNE',
'P5526A Build/NRD90M':'INNE',
'PE-TL10':'INNE',
'PH-1':'INNE',
'PLAYTAB':'INNE',
'PLE-701L':'INNE',
'PLK-L01 Build/HONORPLK-L01':'INNE',
'PLUS':'INNE',
'PMID7102DC':'INNE',
'PRA-LX1 Build/HUAWEIPRA-LX1':'INNE',
'PRA-LX3 Build/HUAWEIPRA-LX3':'INNE',
'PRA507':'INNE',
'PSPC550 Build/LMY47D':'INNE',
'PULP 4G Build/LMY47V':'INNE',
'Pixel':'INNE',
'Pixel 2 Build/OPM1.171019.011':'INNE',
'Pixel 2 Build/OPM1.171019.019':'INNE',
'Pixel 2 Build/OPM1.171019.021':'INNE',
'Pixel 2 Build/OPM2.171019.016':'INNE',
'Pixel 2 XL Build/OPM1.171019.011':'INNE',
'Pixel 2 XL Build/OPM1.171019.013':'INNE',
'Pixel 2 XL Build/OPM1.171019.021':'INNE',
'Pixel 2 XL Build/OPM2.171019.029':'INNE',
'Pixel 2 XL Build/OPM2.171019.029.B1':'INNE',
'Pixel Build/OPM1.171019.011':'INNE',
'Pixel Build/OPM1.171019.012':'INNE',
'Pixel Build/OPM1.171019.016':'INNE',
'Pixel Build/OPM2.171019.029':'INNE',
'Pixel Build/OPM4.171019.016.B1':'INNE',
'Pixel Build/OPR3.170623.013':'INNE',
'Pixel XL Build/OPM1.171019.011':'INNE',
'Pixel XL Build/OPM1.171019.016':'INNE',
'Pixel XL Build/OPM1.171019.021':'INNE',
'Pixel XL Build/OPM4.171019.016.B1':'INNE',
'QMV7A':'INNE',
'QTAIR7 Build/LMY47D':'INNE',
'QTAQZ3 Build/KOT49H':'INNE',
'QTAQZ3 Build/LMY47V':'INNE',
'QTASUN1':'INNE',
'QTASUN1 Build/NRD90M':'INNE',
'QwestIE8':'INNE',
'R1':'INNE',
'R2':'INNE',
'R8106':'INNE',
'R831L':'INNE',
'RCT6203W46 Build/KOT49H':'INNE',
'RCT6223W87':'INNE',
'RCT6303W87M7 Build/MRA58K':'INNE',
'RCT6513W87 Build/MRA58K':'INNE',
'RCT6773W22B':'INNE',
'RCT6K03W13':'INNE',
'RCT6S03W12':'INNE',
'REVVLPLUS':'INNE',
'REX':'INNE',
'RNE-L03 Build/HUAWEIRNE-L03':'INNE',
'RNE-L21 Build/HUAWEIRNE-L21':'INNE',
'RNE-L22 Build/HUAWEIRNE-L22':'INNE',
'RNE-L23 Build/HUAWEIRNE-L23':'INNE',
'RS988':'INNE',
'RS988 Build/MMB29M':'INNE',
'Redmi':'INNE',
'Redmi 3S Build/MMB29M':'INNE',
'Redmi 4A Build/MMB29M':'INNE',
'Redmi 4A Build/N2G47H':'INNE',
'Redmi 4X Build/N2G47H':'INNE',
'Redmi 5 Plus Build/N2G47H':'INNE',
'Redmi Note 3 Build/MMB29M':'INNE',
'Redmi Note 4 Build/MMB29M':'INNE',
'Redmi Note 4 Build/NRD90M':'INNE',
'Redmi Note 4X Build/MRA58K':'INNE',
'Redmi Note 5A Build/N2G47H':'INNE',
'Robin':'INNE',
'S.N.O.W.4':'INNE',
'S471':'INNE',
'S57 Build/KTU84P':'INNE',
'S60 Build/MMB29M':'INNE',
'S6000':'INNE',
'S70V':'INNE',
'SAMSUNG':'SAMSUNG',
'SAMSUNG SM-A300H Build/LRX22G':'SAMSUNG',
'SAMSUNG SM-A310F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A310F/A310FXXU4CRB1 Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A310M Build/LMY47X':'SAMSUNG',
'SAMSUNG SM-A320FL Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A320Y Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A510F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A510M Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-A510M Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A520F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A710M Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A720F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-A730F Build/NMF26X':'SAMSUNG',
'SAMSUNG SM-G530H Build/LRX22G':'SAMSUNG',
'SAMSUNG SM-G530T Build/LMY47X':'SAMSUNG',
'SAMSUNG SM-G531H Build/LMY48B':'SAMSUNG',
'SAMSUNG SM-G532M Build/MMB29T':'SAMSUNG',
'SAMSUNG SM-G550T1 Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-G570M Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-G570M Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G610M Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-G610M Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G800F Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-G850F/G850FXXS2CQD9 Build/LRX22G':'SAMSUNG',
'SAMSUNG SM-G890A Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G891A Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G892A Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G892A Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G900A Build/MMB29M':'SAMSUNG',
'SAMSUNG SM-G900F Build/MMB29M':'SAMSUNG',
'SAMSUNG SM-G900I Build/MMB29M':'SAMSUNG',
'SAMSUNG SM-G900M Build/LRX21T':'SAMSUNG',
'SAMSUNG SM-G900T Build/MMB29M':'SAMSUNG',
'SAMSUNG SM-G903F Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-G920A Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G920F Build/LRX22G':'SAMSUNG',
'SAMSUNG SM-G920F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G920I Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G920P Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G920T Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G925F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G925I Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G925P Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-G925P Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G925T Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G928G Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G930A Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G930F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G930F/XXU2DRC1 Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G930P Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G930R4 Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G930T Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G935A Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G935F Build/MMB29K':'SAMSUNG',
'SAMSUNG SM-G935F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G935P Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G935T Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G935W8 Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G950F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G950F Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G950U Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G950U Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G950U1 Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G950U1 Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G955F Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G955F Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G955U Build/NRD90M':'SAMSUNG',
'SAMSUNG SM-G955U Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G9600 Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G960U Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G9650 Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G965F Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G965U Build/R16NW':'SAMSUNG',
'SAMSUNG SM-G965U1 Build/R16NW':'SAMSUNG',
'SAMSUNG SM-J111M Build/LMY47V':'SAMSUNG',
'SAMSUNG SM-J120H Build/LMY47V':'SAMSUNG',
'SAMSUNG SM-J250M Build/NMF26X':'SAMSUNG',
'SAMSUNG SM
'SM-T670':'SAMSUNG',
'SM-T700 Build/MMB29K':'SAMSUNG',
'SM-T705':'SAMSUNG',
'SM-T710 Build/NRD90M':'SAMSUNG',
'SM-T713 Build/NRD90M':'SAMSUNG',
'SM-T800':'SAMSUNG',
'SM-T800 Build/MMB29K':'SAMSUNG',
'SM-T807T':'SAMSUNG',
'SM-T807V':'SAMSUNG',
'SM-T810':'SAMSUNG',
'SM-T810 Build/NRD90M':'SAMSUNG',
'SM-T813 Build/NRD90M':'SAMSUNG',
'SM-T817T':'SAMSUNG',
'SM-T817V Build/NRD90M':'SAMSUNG',
'SM-T818V':'SAMSUNG',
'SM-T820 Build/NRD90M':'SAMSUNG',
'SM-T825 Build/NRD90M':'SAMSUNG',
'SM-T827R4':'SAMSUNG',
'SM-T827V Build/NRD90M':'SAMSUNG',
'SMART':'INNE',
'SOV33 Build/35.0.D.2.25':'INNE',
'SP7731G':'INNE',
'SPH-L720':'INNE',
'SPH-L720T':'INNE',
'STELLAR':'INNE',
'STF-L09 Build/HUAWEISTF-L09':'INNE',
'STK_Sync_5e':'INNE',
'STUDIO_G_HD':'INNE',
'STV100-1':'INNE',
'STV100-2 Build/MMB29M':'INNE',
'STV100-3':'INNE',
'STV100-4 Build/LMY47V':'INNE',
'Shift Build/LMY47I':'INNE',
'Star':'INNE',
'Stellar':'INNE',
'Studio':'INNE',
'Swift':'INNE',
'T08':'INNE',
'T1':'INNE',
'TA-1003':'INNE',
'TA-1004':'INNE',
'TA-1020':'INNE',
'TA-1025':'INNE',
'TA-1025 Build/NMF26F':'INNE',
'TA-1025 Build/OPR1.170623.026':'INNE',
'TA-1027':'INNE',
'TA-1027 Build/N2G47H':'INNE',
'TA-1027 Build/OPR1.170623.026':'INNE',
'TA-1028 Build/NMF26O':'INNE',
'TA-1028 Build/NRD90M':'INNE',
'TA-1028 Build/O00623':'INNE',
'TA-1032':'INNE',
'TA-1038':'INNE',
'TA-1038 Build/NMF26O':'INNE',
'TA-1038 Build/O00623':'INNE',
'TA-1039 Build/N2G47H':'INNE',
'TA-1039 Build/NMF26F':'INNE',
'TA-1044':'INNE',
'TA-1044 Build/NMF26F':'INNE',
'TA-1044 Build/OPR1.170623.026':'INNE',
'TA-1052':'INNE',
'TAB7':'INNE',
'TOMMY2':'INNE',
'TR10CS1 Build/JDQ39':'INNE',
'TREKKER-M1':'INNE',
'TREKKER-X3 Build/MMB29M':'INNE',
'TRT-L53 Build/HUAWEITRT-L53':'INNE',
'TRT-LX3':'INNE',
'Tab2A7-10F':'INNE',
'Techpad':'INNE',
'Tmovi Build/Vision':'INNE',
'Tornado':'INNE',
'Touch':'INNE',
'Trident/7.0':'INNE',
'Turbo C5 Build/LMY47I':'INNE',
'U':'INNE',
'U FEEL LITE Build/MRA58K':'INNE',
'UL40':'INNE',
'V.40R':'INNE',
'V502015':'INNE',
'VFD':'INNE',
'VK700 Build/LRX22G':'INNE',
'VK810':'INNE',
'VK815':'INNE',
'VKY-L09 Build/HUAWEIVKY-L09':'INNE',
'VS425':'INNE',
'VS425PP Build/LMY47V':'INNE',
'VS500':'INNE',
'VS501 Build/NRD90U':'INNE',
'VS5012 Build/NRD90M':'INNE',
'VS820':'INNE',
'VS835':'INNE',
'VS880':'INNE',
'VS880PP':'INNE',
'VS980 4G Build/LRX22G':'INNE',
'VS985':'INNE',
'VS986 Build/MRA58K':'INNE',
'VS987 Build/NRD90U':'INNE',
'VS988 Build/NRD90U':'INNE',
'VS990 Build/MRA58K':'INNE',
'VS995 Build/NRD90M':'INNE',
'VS996':'INNE',
'VS996 Build/OPR1.170623.026':'INNE',
'VT0701A08':'INNE',
'VTR-AL00 Build/HUAWEIVTR-AL00':'INNE',
'VTR-L09 Build/HUAWEIVTR-L09':'INNE',
'VTR-L29':'INNE',
'Venue':'INNE',
'VerykoolS5030':'INNE',
'Vivo':'INNE',
'WAS-L03T Build/HUAWEIWAS-L03T':'INNE',
'WAS-LX1 Build/HUAWEIWAS-LX1':'INNE',
'WAS-LX1A Build/HUAWEIWAS-LX1A':'INNE',
'WAS-LX2J':'INNE',
'WAS-LX3 Build/HUAWEIWAS-LX3':'INNE',
'WAS-TL10 Build/HUAWEIWAS-TL10':'INNE',
'WOW64':'INNE',
'Wileyfox':'INNE',
'Win64':'INNE',
'Windows':'WINDOWS',
'Windows NT 6.1':'WINDOWS',
'Windows NT 6.2':'WINDOWS',
'X10':'XT',
'X3402':'XT',
'X78':'XT',
'X900+':'XT',
'XT1003':'XT',
'XT1008':'XT',
'XT1008 Build/LPBS23.13-56-2':'XT',
'XT1021':'XT',
'XT1021 Build/KXC21.5-40':'XT',
'XT1021 Build/LPCS23.13-34.8-3':'XT',
'XT1023':'XT',
'XT1030 Build/SU6-7.7':'XT',
'XT1031':'XT',
'XT1032':'XT',
'XT1032 Build/KXB20.9-1.10-1.24-1.1':'XT',
'XT1032 Build/KXB21.14-L1.40':'XT',
'XT1032 Build/LPBS23.13-56-2':'XT',
'XT1032 Build/LPBS23.13-57-2':'XT',
'XT1033':'XT',
'XT1040':'XT',
'XT1053 Build/LPAS23.12-21.7-1':'XT',
'XT1055':'XT',
'XT1058':'XT',
'XT1058 Build/LPAS23.12-21.7-1':'XT',
'XT1060':'XT',
'XT1063':'XT',
'XT1063 Build/MPB24.65-34':'XT',
'XT1063 Build/MPB24.65-34-3':'XT',
'XT1064':'XT',
'XT1064 Build/MPB24.65-34-3':'XT',
'XT1068':'XT',
'XT1072':'XT',
'XT1080':'XT',
'XT1080 Build/SU6-7.7':'XT',
'XT1092':'XT',
'XT1094':'XT',
'XT1095':'XT',
'XT1096':'XT',
'XT1097':'XT',
'XT1225':'XT',
'XT1254':'XT',
'XT1254 Build/MCG24.251-5-5':'XT',
'XT1528':'XT',
'XT1563':'XT',
'XT1563 Build/MPD24.107-52':'XT',
'XT1563 Build/MPD24.65-25':'XT',
'XT1563 Build/MPDS24.107-52-5':'XT',
'XT1565':'XT',
'XT1572 Build/NPHS25.200-15-8':'XT',
'XT1575':'XT',
'XT1575 Build/NPHS25.200-23-1':'XT',
'XT1580':'XT',
'XT1580 Build/NPKS25.200-12-9':'XT',
'XT1580 Build/NPKS25.200-17-8':'XT',
'XT1585 Build/NCK25.118-10.5':'XT',
'XT1609':'XT',
'XT1609 Build/MPIS24.241-2.35-1-17':'XT',
'XT1609 Build/NPIS26.48-38-3':'XT',
'XT1635-01':'XT',
'XT1635-01 Build/NDNS26.118-23-12-3':'XT',
'XT1635-02':'XT',
'XT1635-02 Build/NPN26.118-22-2':'XT',
'XT1635-02 Build/OPN27.76-12-22':'XT',
'XT1650':'XT',
'XT1650 Build/NCLS26.118-23-13-3':'XT',
'XT1650 Build/NCLS26.118-23-13-6-5':'XT',
'XT1650 Build/NPLS26.118-20-5-11':'XT',
'XT1650 Build/NPLS26.118-20-5-3':'XT',
'XT1680':'XT',
'XT1710-02':'XT',
'XT1710-02 Build/NDSS26.118-23-15':'XT',
'XT1710-02 Build/NDSS26.118-23-19-6':'XT',
'XT890 Build/9.8.2I-50_SML-25':'XT',
'Y550-L02':'INNE',
'Y635-L03 Build/HuaweiY635-L03':'INNE',
'YOGA':'INNE',
'YOLO':'INNE',
'Z':'INNE',
'Z2':'INNE',
'Z410':'INNE',
'Z557BL':'INNE',
'Z798BL Build/MMB29M':'INNE',
'Z799VL':'INNE',
'Z812':'INNE',
'Z813 Build/LMY47O':'INNE',
'Z831':'INNE',
'Z832 Build/MMB29M':'INNE',
'Z833':'INNE',
'Z835 Build/NMF26V':'INNE',
'Z836BL':'INNE',
'Z837VL':'INNE',
'Z839':'INNE',
'Z9 PLUS Build/NRD90M':'INNE',
'Z955A':'INNE',
'Z956 Build/MMB29M':'INNE',
'Z959 Build/LMY47V':'INNE',
'Z963VL':'INNE',
'Z965 Build/NMF26V':'INNE',
'Z970':'INNE',
'Z971':'INNE',
'Z981 Build/MMB29M':'INNE',
'Z982 Build/NMF26V':'INNE',
'Z983 Build/NMF26F':'INNE',
'ZA409':'INNE',
'ZA509':'INNE',
'ZA990':'INNE',
'ZEIA8':'INNE',
'ZTE':'INNE',
'ZTE A2017U Build/NRD90M':'INNE',
'ZTE BLADE A321 Build/NMF26F':'INNE',
'ZTE BLADE A512 Build/MMB29M':'INNE',
'ZTE BLADE A6 Build/NMF26F':'INNE',
'ZTE BLADE V8 MINI Build/NRD90M':'INNE',
'ZTE Blade A511 Build/MRA58K':'INNE',
'ZTE Blade L5 Build/LMY47I':'INNE',
'ZTE-Z835':'INNE',
'ZTE-Z956':'INNE',
'ZUR70016':'INNE',
'ZUUM_ZEN_I Build/LRX21M':'INNE',
'en-gb':'INNE',
'en-us':'INNE',
'es-mx':'INNE',
'es-us':'INNE',
'gxq6580_weg_l Build/LMY47I':'INNE',
'hi6210sft Build/MRA58K':'INNE',
'hp2015':'INNE',
'iOS Device':'iOS',
'iPhone':'iOS',
'iris 820 Build/MRA58K':'INNE',
'iris 870 Build/MRA58K':'INNE',
'iris50':'INNE',
'iris702':'INNE',
'iris80':'INNE',
'm3':'INNE',
'moto':'INNE',
'moto g(6) play Build/OPP27.61-14-4':'MOTO',
'moto x4 Build/NPW26.83-18-2-0-4':'MOTO',
'moto x4 Build/NPW26.83-42':'MOTO',
'moto x4 Build/OPW27.57-40':'MOTO',
'moto x4 Build/OPWS27.57-40-14':'MOTO',
'moto x4 Build/OPWS27.57-40-6':'MOTO',
'orbis':'INNE',
'rv:11.0':'RV',
'rv:14.0':'RV',
'rv:29.0':'RV',
'rv:31.0':'RV',
'rv:33.0':'RV',
'rv:35.0':'RV',
'rv:37.0':'RV',
'rv:38.0':'RV',
'rv:39.0':'RV',
'rv:41.0':'RV',
'rv:42.0':'RV',
'rv:43.0':'RV',
'rv:44.0':'RV',
'rv:45.0':'RV',
'rv:46.0':'RV',
'rv:47.0':'RV',
'rv:48.0':'RV',
'rv:49.0':'RV',
'rv:50.0':'RV',
'rv:51.0':'RV',
'rv:52.0':'RV',
'rv:52.9':'RV',
'rv:53.0':'RV',
'rv:54.0':'RV',
'rv:55.0':'RV',
'rv:56.0':'RV',
'rv:57.0':'RV',
'rv:58.0':'RV',
'rv:59.0':'RV',
'rv:60.0':'RV',
'rv:61.0':'RV',
'verykool':'INNE',
'verykoolS5005':'INNE',
'verykoolS5019':'INNE',
'verykoolS5524':'INNE',
'verykoolS5525':'INNE',
'verykoolS5530 Build/LMY47I':'INNE',
'verykools4009':'INNE',
'verykools5004':'INNE',
'verykools5034':'INNE',
'verykools5035':'INNE',
'vivo':'INNE',
'xs-Z47b7VqTMxs':'INNE'},inplace=True)
df['id_33'].replace({'480x320':'<1000',
'600x450':'<1000',
'640x360':'<1000',
'768x576':'<1000',
'800x600':'<1000',
'801x480':'<1000',
'855x480':'<1000',
'921x691':'<1000',
'960x540':'<1000',
'960x640':'<1000',
'976x600':'<1000',
'1023x767':'1000<x<1500',
'1023x768':'1000<x<1500',
'1024x552':'1000<x<1500',
'1024x600':'1000<x<1500',
'1024x640':'1000<x<1500',
'1024x767':'1000<x<1500',
'1024x768':'1000<x<1500',
'1024x819':'1000<x<1500',
'1025x768':'1000<x<1500',
'1062x630':'1000<x<1500',
'1092x614':'1000<x<1500',
'1093x615':'1000<x<1500',
'1120x700':'1000<x<1500',
'1136x640':'1000<x<1500',
'1138x640':'1000<x<1500',
'1152x648':'1000<x<1500',
'1152x720':'1000<x<1500',
'1152x864':'1000<x<1500',
'1184x720':'1000<x<1500',
'1188x720':'1000<x<1500',
'1200x675':'1000<x<1500',
'1200x720':'1000<x<1500',
'1229x691':'1000<x<1500',
'1232x800':'1000<x<1500',
'1239x697':'1000<x<1500',
'1264x924':'1000<x<1500',
'1272x960':'1000<x<1500',
'1279x1023':'1000<x<1500',
'1279x1024':'1000<x<1500',
'1280x1023':'1000<x<1500',
'1280x1024':'1000<x<1500',
'1280x1025':'1000<x<1500',
'1280x600':'1000<x<1500',
'1280x620':'1000<x<1500',
'1280x712':'1000<x<1500',
'1280x720':'1000<x<1500',
'1920x1079':'1500<x<2000',
'1920x1080':'1500<x<2000',
'1920x1081':'1500<x<2000',
'1920x1200':'1500<x<2000',
'1920x1201':'1500<x<2000',
'1920x1279':'1500<x<2000',
'1920x1280':'1500<x<2000',
'1920x1281':'1500<x<2000',
'1920x975':'1500<x<2000',
'1921x1080':'1500<x<2000',
'1921x1081':'1500<x<2000',
'2000x1125':'2000<x<2500',
'2001x1125':'2000<x<2500',
'2010x1080':'2000<x<2500',
'2048x1080':'2000<x<2500',
'2048x1152':'2000<x<2500',
'2048x1278':'2000<x<2500',
'2048x1280':'2000<x<2500',
'2048x1536':'2000<x<2500',
'2049x1152':'2000<x<2500',
'2049x1536':'2000<x<2500',
'2076x1080':'2000<x<2500',
'2100x1312':'2000<x<2500',
'2112x1188':'2000<x<2500',
'2159x1439':'2000<x<2500',
'2159x1440':'2000<x<2500',
'2160x1080':'2000<x<2500',
'2160x1081':'2000<x<2500',
'2160x1215':'2000<x<2500',
'2160x1350':'2000<x<2500',
'2160x1439':'2000<x<2500',
'2160x1440':'2000<x<2500',
'2208x1242':'2000<x<2500',
'2220x1080':'2000<x<2500',
'2220x1081':'2000<x<2500',
'2224x1668':'2000<x<2500',
'2255x1503':'2000<x<2500',
'2256x1504':'2000<x<2500',
'2304x1296':'2000<x<2500',
'2304x1440':'2000<x<2500',
'2368x1440':'2000<x<2500',
'2392x1440':'2000<x<2500',
'2400x1350':'2000<x<2500',
'2400x1500':'2000<x<2500',
'2400x1600':'2000<x<2500',
'2436x1125':'2000<x<2500',
'2520x1575':'2500<x<3000',
'2552x1337':'2500<x<3000',
'2559x1439':'2500<x<3000',
'2559x1440':'2500<x<3000',
'2560x1080':'2500<x<3000',
'2560x1440':'2500<x<3000',
'2560x1600':'2500<x<3000',
'2560x1700':'2500<x<3000',
'2560x1800':'2500<x<3000',
'2561x1442':'2500<x<3000',
'2562x1442':'2500<x<3000',
'2591x1619':'2500<x<3000',
'2672x1440':'2500<x<3000',
'2700x1800':'2500<x<3000',
'2710x1440':'2500<x<3000',
'2732x2048':'2500<x<3000',
'2735x1823':'2500<x<3000',
'2735x1825':'2500<x<3000',
'2736x1823':'2500<x<3000',
'2736x1824':'2500<x<3000',
'2737x1825':'2500<x<3000',
'2800x1575':'2500<x<3000',
'2816x1584':'2500<x<3000',
'2816x1760':'2500<x<3000',
'2880x1440':'2500<x<3000',
'2880x1442':'2500<x<3000',
'2880x1620':'2500<x<3000',
'2880x1800':'2500<x<3000',
'2882x1442':'2500<x<3000',
'2960x1440':'2500<x<3000',
'2961x1440':'2500<x<3000',
'2961x1442':'2500<x<3000',
'2999x2000':'2500<x<3000',
'3000x2000':'x>3000',
'3001x2000':'x>3000',
'3072x1728':'x>3000',
'3199x1800':'x>3000',
'3200x1800':'x>3000',
'3200x2000':'x>3000',
'3201x1800':'x>3000',
'3240x2160':'x>3000',
'3360x1050':'x>3000',
'3360x1890':'x>3000',
'3360x2100':'x>3000',
'3440x1440':'x>3000',
'3441x1440':'x>3000',
'3520x1980':'x>3000',
'3600x2250':'x>3000',
'3696x2310':'x>3000',
'3838x2158':'x>3000',
'3838x2160':'x>3000',
'3839x2159':'x>3000',
'3839x2160':'x>3000',
'3840x1080':'x>3000',
'3840x1600':'x>3000',
'3840x2160':'x>3000',
'3840x2162':'x>3000',
'3840x2400':'x>3000',
'3841x2161':'x>3000',
'3843x2163':'x>3000',
'4096x2304':'x>3000',
'4200x2625':'x>3000',
'4499x2999':'x>3000',
'4500x3000':'x>3000',
'5040x3150':'x>3000',
'5120x2880':'x>3000',
'5760x1080':'x>3000',
'5760x3240':'x>3000',
'6016x3384':'x>3000',
'6400x3600':'x>3000',
'6720x3780':'x>3000',
'7500x5000':'x>3000',},inplace=True)

# %%
print('Po transformacji: ')
print('Poziomy id_30: ',len(df['id_30'].value_counts()))
print('Poziomy id_31: ',len(df['id_31'].value_counts()))
print('Poziomy DeviceInfo: ',len(df['DeviceInfo'].value_counts()))
print('Poziomy P_emaildomain: ',len(df['P_emaildomain'].value_counts()))
print('Poziomy R_emaildomain: ',len(df['R_emaildomain'].value_counts()))

# %%
numFeatures=list(df)
for x in catFeatures:
  numFeatures.remove(x)

numFeatures.remove('isFraud')

# %%
features = list(df)
features.remove('isFraud')
target='isFraud'

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
minfos=[]

for var in features: 
  mutual_info_classif(df[var].values.reshape(-1,1), df[target].values)
  minfos.append(mutual_info_classif(df[var].values.reshape(-1,1),df[target].values)[0])
imp = list(zip(minfos, features))
imp.sort(reverse=True)
imp

# %%
from sklearn import preprocessing
mapy={}
for feature in catFeatures:
    le = preprocessing.LabelEncoder()
    df[feature] = le.fit_transform(df[feature])
    mapy[feature] = le

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import average_precision_score

# %%
len(features)

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV

x_train, x_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.20, random_state=42, shuffle=True)

feature_selector = RFECV(RandomForestClassifier(), step=10, scoring='average_precision', cv=5, verbose=1)
feature_selector.fit(x_train, y_train)
print('Wybrane zmienne:', feature_selector.n_features_)

# %%
selected_features = [f for f in x_train.columns[feature_selector.ranking_ == 1]]
selected_features

# %%
_, x_train_valid_part, _, y_train_valid_part = train_test_split(x_test, y_test, test_size=0.25, random_state=2020)
rf_model = RandomForestClassifier(n_estimators=100).fit(x_train, y_train)
y_all_features = rf_model.predict_proba(x_train_valid_part)[:,1]
score_all_features = average_precision_score(y_train_valid_part, y_all_features)
print('Wynik / Wszystkie zmienne:', score_all_features)

# %%
y_selected_features = feature_selector.estimator_.predict_proba(x_train_valid_part[selected_features])[:,1]
score_selected_features = average_precision_score(y_train_valid_part, y_selected_features)
print('Wynik / Wybrane zmienne:', score_selected_features)

# %%
feature_importance_df = pd.concat([
    pd.Series(x_train.columns),
    pd.Series(rf_model.feature_importances_)], axis=1)
feature_importance_df.columns = ['featureName', 'importance']

feature_importance_df['selected'] = feature_importance_df['featureName'].map(lambda x: x in selected_features)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(feature_importance_df.sort_values(by=['importance'], ascending=False))

# %%
#ft2=['isFraud','id_01','id_02','id_05','id_06','id_13','id_12','id_19','id_20','id_30','id_31','ProductCD', 'DeviceType','id_33','DeviceInfo','TransactionAmt','card1','card2','card3','card4', 'card5', 'card6','addr1','dist2','P_emaildomain','R_emaildomain','C1','C2','C4','C6','C7','C8','C10','C11','C12','C13','C14','D2','D6','D8','D9','V44','V45','V86','V87','V149','V156','V188','V189','V200','V201','V203','V210','V245','V257','V258','V259','V264','V265']
ft2=['id_01','id_02','id_05','id_06','id_13','id_12','id_19','id_20','id_30','id_31','ProductCD', 'DeviceType','id_33','DeviceInfo','TransactionAmt','card1','card2','card3','card4', 'card5', 'card6','addr1','dist2','P_emaildomain','R_emaildomain','C1','C2','C4','C6','C7','C8','C10','C11','C12','C13','C14','D2','D6','D8','D9','V44','V45','V86','V87','V149','V156','V188','V189','V200','V201','V203','V210','V245','V257','V258','V259','V264','V265']

# %%
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, recall_score, average_precision_score


def wrapper(model=RandomForestClassifier, nFolds = 5, randomState=2020, debug=False, features=features, baza=df, sampling=False, sampler=False,saveModels = False, *args, **kwargs):
    kf = KFold(n_splits=nFolds, shuffle=True, random_state=randomState)

    testResults = []
    recallTestResults=[]
    recallTrainResults=[]
    predictions=[]
    trainResults = []
    
    indices = []
    models = []

    for train, test in kf.split(baza.index.values):
        clf = model(*args, **kwargs, random_state=randomState)
        if debug:
            print(clf)
        X_train, y_train = baza.iloc[train][features], baza.iloc[train][target] 
        X_test, y_test = baza.iloc[test][features], baza.iloc[test][target]

        if sampling:
          X_train, y_train = sampler.fit_sample(X_train, y_train)

        clf.fit(X_train, y_train)
        predsTrain = clf.predict_proba(X_train)[:,1]
        preds = clf.predict_proba(X_test)[:,1]
                              
        predictions.append(preds.tolist().copy())
        
        indices.append(baza.iloc[test].index.tolist().copy())
        
        trainScore = roc_auc_score((y_train==1).astype(int), predsTrain)
        testScore = roc_auc_score((y_test==1).astype(int), preds)
        trainResults.append(trainScore)
        testResults.append(testScore)
        recallTrainScore = average_precision_score((y_train==1).astype(int), predsTrain)
        recallTestScore = average_precision_score((y_test==1).astype(int), preds)
        recallTrainResults.append(recallTrainScore)
        recallTestResults.append(recallTestScore)

        if debug:
            print("Train AUC:", trainScore,
                  "Valid AUC:", testScore,
                  )
            
        if saveModels:
          models.append(clf)

        
    return trainResults, testResults, predictions, indices, recallTestResults, recallTrainResults, models

# %%
for k in [features, selected_features, ft2]:

  trainResults, testResults, predictions, indices, recallTestResults, recallTrainResults, models = wrapper(features=k)
  print(np.mean(recallTestResults))

# %%
ft2=['isFraud','id_01','id_02','id_05','id_06','id_13','id_12','id_19','id_20','id_30','id_31','ProductCD', 'DeviceType','id_33','DeviceInfo','TransactionAmt','card1','card2','card3','card4', 'card5', 'card6','addr1','dist2','P_emaildomain','R_emaildomain','C1','C2','C4','C6','C7','C8','C10','C11','C12','C13','C14','D2','D6','D8','D9','V44','V45','V86','V87','V149','V156','V188','V189','V200','V201','V203','V210','V245','V257','V258','V259','V264','V265']
df[ft2].to_csv('/content/drive/My Drive/zmienne_final.csv')
